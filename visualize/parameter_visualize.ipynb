# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import matplotlib.pyplot as plt

# %%
for p in [3,5,8,12,16]:
    parameter_path =  "../experiment_data/complete/NIPS/persona={}/train_paramerter.npy".format(p)
    param = np.load(parameter_path)
    print("persona:",p)
    print("T",param[:p])
    print("e",param[p:2*p])
    print("r",param[2*p:3*p])
    print("w",param[3*p:4*p])
    ratio_path =  "../experiment_data/complete/NIPS/persona={}/train_persona_ration.npy".format(p)
    data = np.load(ratio_path)[0]
    print(data.sum(axis=0)/data.sum())
    print("-------------------")
# Out:
# persona: 3
# T [0.9174763  0.92251724 0.9318305 ]
# e [1.0734078 1.0613116 1.0679276]
# r [0.49423337 0.44870907 0.49411854]
# w [1.0053768 1.0638089 1.0055852]
# [0.15809868 0.8106512  0.03125   ]
# -------------------
# persona: 5
# T [0.9100301  0.90999895 0.910025   0.9100295  0.91002184]
# e [1.0899576 1.0900042 1.0899564 1.0899429 1.0898659]
# r [0.41016227 0.40999624 0.41022655 0.41023034 0.4103682 ]
# w [1.089346  1.0899603 1.0891414 1.0890775 1.0888975]
# [0.01854661 0.8125     0.04200307 0.12500004 0.00195028]
# -------------------
# persona: 8
# T [0.9279632  0.91385823 0.93045044 0.9270298  0.93540007 0.91130877
#  0.9575589  0.9311056 ]
# e [1.0632185 1.0698694 1.0627481 1.0645485 1.0563637 1.0712764 1.0425404
#  1.0685635]
# r [0.49431568 0.45204645 0.49416256 0.49453104 0.49422178 0.451202
#  0.45871344 0.49399665]
# w [1.0049125 1.0592127 1.0053012 1.004556  1.0052559 1.0513705 1.0392605
#  1.005559 ]
# [9.5320046e-03 5.3707197e-02 5.1034659e-02 1.9332963e-03 9.3749113e-02
#  7.5879377e-01 1.3499599e-12 3.1250000e-02]
# -------------------
# persona: 12
# T [0.9179714  0.9610506  0.92080814 0.9182571  0.9308595  0.9552061
#  0.93084115 0.9232151  0.9175974  0.94195837 0.91811    0.9202773 ]
# e [1.0698327 1.0325717 1.0589956 1.0662407 1.0555849 1.0363723 1.0574712
#  1.0640422 1.0698295 1.0476395 1.0641898 1.0795346]
# r [0.49413475 0.4661022  0.4941795  0.49409565 0.49417093 0.4620496
#  0.4941487  0.49409515 0.49426317 0.49432403 0.49415028 0.49390465]
# w [1.0056238 1.0499123 1.0054134 1.0057461 1.0055833 1.0496335 1.0055689
#  1.0053415 1.0052536 1.0053904 1.0053556 1.0058658]
# [3.0228103e-02 1.5759997e-01 4.7298295e-06 6.4451699e-05 3.3704441e-02
#  6.5490097e-01 2.6855618e-02 3.1426381e-02 6.4469880e-04 3.3189055e-02
#  1.3160337e-04 3.1250004e-02]
# -------------------
# persona: 16
# T [0.9100632  0.91002107 0.9101126  0.9100599  0.91006756 0.90999925
#  0.9143375  0.910018   0.91038203 0.91004723 0.91006345 0.91036725
#  0.9100284  0.9146474  0.9100372  0.91486996]
# e [1.0899543 1.0899762 1.0898905 1.0899633 1.0899216 1.0900029 1.0834925
#  1.0899682 1.0889884 1.089945  1.0899624 1.089103  1.0899638 1.0841033
#  1.0899404 1.0841894]
# r [0.41013974 0.41020226 0.41013497 0.41016045 0.41011748 0.41001737
#  0.41595447 0.41026953 0.4102846  0.4101329  0.41015795 0.41023624
#  0.41020444 0.4171557  0.41018245 0.41531906]
# w [1.089441  1.0892048 1.0894117 1.089335  1.0895097 1.089947  1.0829092
#  1.088925  1.089298  1.0892786 1.0893998 1.0849924 1.0890881 1.07887
#  1.0893534 1.0768386]
# [6.17447682e-03 9.83835831e-02 3.12340800e-02 2.10693083e-03
#  2.76925275e-05 5.50453663e-01 4.19970583e-08 8.39574710e-02
#  6.26367125e-07 1.24999605e-01 2.29402743e-02 1.59197753e-05
#  6.45577237e-02 1.80469542e-07 1.51475370e-02 1.72806878e-07]
# -------------------

# %%
for p in [5,25,50]:
    parameter_path =  "../experiment_data/complete/DBLP/persona={}/train_paramerter.npy".format(p)
    param = np.load(parameter_path)
    print("persona:",p)
    print("T",param[:p])
    print("e",param[p:2*p])
    print("r",param[2*p:3*p])
    print("w",param[3*p:4*p])
    ratio_path =  "../experiment_data/complete/DBLP/persona={}/train_persona_ration.npy".format(p)
    data = np.load(ratio_path)[0]
    print(data.sum(axis=0)/data.sum())
    print("-------------------")
# Out:
# persona: 5
# T [0.9100024  0.9099983  0.90999836 0.9100151  0.91006744]
# e [1.0899991 1.0900035 1.0900036 1.0899875 1.089935 ]
# r [0.41000175 0.41000116 0.410002   0.41000065 0.41000012]
# w [1.0899936 1.089996  1.0899985 1.0900011 1.0900023]
# [0.5676579  0.2983115  0.08751761 0.03649865 0.01001443]
# -------------------
# persona: 25
# T [0.91002434 0.9100238  0.91008896 0.9100849  0.9100466  0.9100418
#  0.9100217  0.91001576 0.9100151  0.91008633 0.9100673  0.9100924
#  0.91009384 0.9100551  0.91001534 0.91005707 0.91009    0.9100329
#  0.91001356 0.91009426 0.91059893 0.9100342  0.9100887  0.91002053
#  0.9108831 ]
# e [1.0899733 1.0899763 1.0899163 1.0899216 1.0899589 1.0899558 1.0899818
#  1.0899909 1.0899874 1.0899197 1.0899366 1.0899105 1.0899113 1.0899475
#  1.0899904 1.0899432 1.0899138 1.0899725 1.0899912 1.089889  1.0894119
#  1.0899671 1.0899212 1.0899832 1.0891984]
# r [0.49054688 0.48846582 0.49342862 0.49188137 0.49061856 0.4939418
#  0.4640681  0.4880746  0.48894414 0.4937669  0.49240085 0.49368036
#  0.48958898 0.49323314 0.48989    0.49147305 0.49367678 0.48973736
#  0.49092856 0.48772162 0.48821455 0.48799437 0.49096775 0.49391595
#  0.48287383]
# w [1.0091796 1.0114204 1.0066595 1.0082009 1.0103141 1.0060037 1.033857
#  1.0116463 1.0107255 1.0064349 1.0075632 1.0066525 1.010584  1.0072387
#  1.0098767 1.0084147 1.0063906 1.0100583 1.0085624 1.0126634 1.0110587
#  1.014788  1.0072242 1.0061712 1.0249372]
# [1.20743714e-01 3.66206355e-02 1.44102713e-04 2.74595863e-04
#  9.88655817e-03 7.89691806e-02 5.86946821e-03 1.41214076e-02
#  1.37050054e-03 6.19369734e-04 1.41444534e-05 5.13909299e-06
#  2.66026145e-05 8.25969595e-03 2.70955600e-02 1.55620754e-03
#  1.31514207e-05 5.16056418e-02 2.25644827e-01 6.87887081e-08
#  2.00000009e-03 3.85999531e-01 1.56058883e-02 1.15543595e-02
#  2.00000009e-03]
# -------------------
# persona: 50
# T [0.9099996  0.9099982  0.9099984  0.91000456 0.9100018  0.91000044
#  5.67892785e-05 2.07902965e-04 1.03684302e-04 2.91750045e-03
#  2.00000009e-03 3.68942157e-03 5.05741955e-05 9.55543853e-03
#  2.00000009e-03 1.45207552e-04]
# -------------------

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [4,5,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 4
# persona: 5
# persona: 8
# persona: 12
# persona: 16

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [4,5,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/NIPS/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[3*p:4*p],param[2*p:3*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 4
# persona: 5
# persona: 8
# persona: 12
# persona: 16

# %% [markdown]
# T::エッジの貼りやすさ(繋がりやすい)
# 大
# e:エッジの貼りやすさ(繋がりやすい)
# 小
# →右下ほど他と繋がりやすい
# →左上ほど他と繋がりにくい
# r:影響力
# 大　影響力ある
# w:属性値の維持(頑固さ)

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [4,5,8,12,16]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 7
#       5 p = p_num[c]
#       6 parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
# ----> 7 param = np.load(parameter_path)
#      10 ax.scatter(param[:p],param[p:2*p], lw=2, label='persona{}'.format(p), color=colors[c])
#      11 print("persona:",p)
#
# File ~/coma/.venv/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiment_data/DBLP/param/persona=4/paramerter.npy'

# %%
fig, ax = plt.subplots(1)
colors = ["blue","red","green","orange","brown","purple","black"]
p_num = [5,6,8,12]
for c in range(len(p_num)):
    p = p_num[c]
    parameter_path =  "experiment_data/DBLP/param/persona={}/paramerter.npy".format(p)
    param = np.load(parameter_path)
   
    
    ax.scatter(param[3*p:4*p],param[2*p:3*p], lw=2, label='persona{}'.format(p), color=colors[c])
    print("persona:",p)
    #print("T",param[:p])
    #print("e",param[p:2*p])
    #print("r",param[2*p:3*p])
    #print("w",param[3*p:4*p])
    #print("-------------------")
# Out:
# persona: 5
# persona: 6
# persona: 8
# persona: 12
